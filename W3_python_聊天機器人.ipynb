# %% [markdown]
# <a href="https://colab.research.google.com/github/Alinananaaa/2025_programming/blob/main/W3_python_%E8%81%8A%E5%A4%A9%E6%A9%9F%E5%99%A8%E4%BA%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
userdata.get('692337927035')
# Out:
# 'AIzaSyCTC0mswtvsbqRjSWMiMvZhgvZXjP_qzYY'

# %%
from google import genai

client = genai.Client(api_key="AIzaSyCTC0mswtvsbqRjSWMiMvZhgvZXjP_qzYY")

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=["今日投資運勢如何？請推薦我一支股票"])
print(response.text)

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1nsWTkfZFuEko8QB4q-jdoj6YDiiY2uvVIjeZNOg8kbQ/edit?usp=sharing')

# %%
gsheets
# Out:
# <Spreadsheet 'W3_python_聊天機器人' id:1nsWTkfZFuEko8QB4q-jdoj6YDiiY2uvVIjeZNOg8kbQ>

# %%
from gspread_dataframe import set_with_dataframe

# 選擇要更新的工作表（選擇第一個工作表）
worksheet = gsheets.get_worksheet(0)  # 如果是其他工作表，可以用 get_worksheet(index)

# %%
worksheet
# Out:
# <Worksheet '工作表1' id:0>

# %%
# 取得 Google Sheets 內容
data = worksheet.get_all_values()  # 取得所有儲存格資料，回傳為 2D 陣列
df = pd.DataFrame(data)

# %%
df
# Out:
#       0      1
# 0    運勢     推薦
# 1     好   2330
# 2    很好   0050
# 3    超棒  00878
# 4  一定要買  00919

# %%
prompt = f'我想請你依據 {df.to_string()}的日期，進行摘要且提供股市建議'

# %%
prompt
# Out:
# '我想請你依據       0      1\n0    運勢     推薦\n1     好   2330\n2    很好   0050\n3    超棒  00878\n4  一定要買  00919的日期，進行摘要且提供股市建議'

# %%
from google.colab import userdata
apikey = userdata.get('GOOGLE_API_KEY')

# %%
import google.generativeai as genai
genai.configure(api_key = apikey)
model = genai.GenerativeModel("gemini-2.0-flash")
response = model.generate_content(prompt)
print(response.text)
# Out:
# 好的，我將根據您提供的資料進行分析，並提供股市建議，但請注意，這些建議僅供參考，投資前請務必謹慎評估：
#
# **資料摘要：**
#
# |  | 0 (運勢) | 1 (推薦) |
# |---|---|---|
# | 0 | 運勢 | 推薦 |
# | 1 | 好 | 2330 (台積電) |
# | 2 | 很好 | 0050 (元大台灣50) |
# | 3 | 超棒 | 00878 (國泰永續高股息) |
# | 4 | 一定要買 | 00919 (群益台灣精選高息) |
#
# **分析：**
#
# *   **運勢描述：** 從「好」、「很好」到「超棒」、「一定要買」，可以解讀為對股市的樂觀程度逐步增強。
# *   **推薦標的：**
#     *   **2330 (台積電)：** 代表台灣科技產業的龍頭，通常被視為穩定成長的標的。
#     *   **0050 (元大台灣50)：** 代表台灣股市整體表現，追蹤台灣前50大上市公司的指數。
#     *   **00878 (國泰永續高股息)：** 以永續經營為主題，同時提供高股息，適合追求穩定收益的投資人。
#     *   **00919 (群益台灣精選高息)：** 也是高股息ETF，但選股策略可能與00878有所不同，可能更注重當期股息的表現。
#
# **股市建議 (僅供參考)：**
#
# 1.  **整體策略：**
#     *   如果您的風險承受度較高，且相信股市未來走勢良好，可以考慮適度增加股票的配置比例。
#     *   如果您的風險承受度較低，則建議維持現有配置，或考慮增加防禦型標的的比例。
#
# 2.  **個股/ETF建議：**
#     *   **台積電 (2330)：** 如果看好科技產業的長期發展，可以考慮持有。
#     *   **元大台灣50 (0050)：** 如果想參與台灣股市的整體成長，0050是一個不錯的選擇。
#     *   **高股息ETF (00878、00919)：** 如果追求穩定的現金流，可以考慮配置高股息ETF。
#     *   **配置考量：**
#         *   **分散風險：** 不要將所有資金集中在單一標的上，建議分散投資不同的個股或ETF。
# ...

# %%
type(response.text)
# Out:
# str

# %%
from io import StringIO

# 轉換為 DataFrame
df_all = pd.read_csv(StringIO(response.text))

# %%
df_all
# Out:
#    好的，我將根據您提供的資料進行分析，並提供股市建議，但請注意，這些建議僅供參考，投資前請務必謹慎評估：
# 0                                           **資料摘要：**
# 1                              |  | 0 (運勢) | 1 (推薦) |
# 2                                       |---|---|---|
# 3                                     | 0 | 運勢 | 推薦 |
# 4                              | 1 | 好 | 2330 (台積電) |
# 5                          | 2 | 很好 | 0050 (元大台灣50) |
# 6                        | 3 | 超棒 | 00878 (國泰永續高股息) |
# 7                     | 4 | 一定要買 | 00919 (群益台灣精選高息) |
# 8                                             **分析：**
# 9   *   **運勢描述：** 從「好」、「很好」到「超棒」、「一定要買」，可以解讀為對股市的樂...
# 10                                      *   **推薦標的：**
# 11      *   **2330 (台積電)：** 代表台灣科技產業的龍頭，通常被視為穩定成長的標的。
# 12      *   **0050 (元大台灣50)：** 代表台灣股市整體表現，追蹤台灣前50大...
# 13      *   **00878 (國泰永續高股息)：** 以永續經營為主題，同時提供高股息，...
# 14      *   **00919 (群益台灣精選高息)：** 也是高股息ETF，但選股策略可能...
# 15                                   **股市建議 (僅供參考)：**
# ...

# %%
# 選擇要更新的工作表（選擇第一個工作表）
worksheet_allcommand = gsheets.get_worksheet(1)  # 如果是其他工作表，可以用 get_worksheet(index)
# 將 DataFrame 寫入 Google Sheets
set_with_dataframe(worksheet_allcommand, df_all)

# %%
def translate_text(text, target_language):
    prompt = f"Translate the following text to {target_language}: {text}"
    response = model.generate_content(prompt)
    return response.text

# %%
def chat_bot():
    print("Welcome to the translation chatbot!")
    print("Type 'exit' to quit.")

    target_language = input("Please specify the target language (e.g., French, Spanish, Chinese): ")

    while True:
        user_input = input("Enter the text you want to translate: ")

        if user_input.lower() == "exit":
            print("Goodbye!")
            break

        translation = translate_text(user_input, target_language)
        print(f"Translation to {target_language}: {translation}")
